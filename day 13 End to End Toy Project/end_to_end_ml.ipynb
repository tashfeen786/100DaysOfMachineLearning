# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("F:\\datasets\\placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 89   4.9  151.0
# 21   7.1  151.0
# 15   5.1  176.0
# 52   7.0  175.0
# 16   5.2  224.0
# ..   ...    ...
# 47   5.2  161.0
# 44   7.5   61.0
# 46   5.3  114.0
# 40   4.9  134.0
# 0    6.8  123.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 89    0
# 21    1
# 15    0
# 52    1
# 16    0
#      ..
# 47    0
# 44    1
# 46    0
# 40    0
# 0     1
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 82   6.5   37.0
# 56   6.1   65.0
# 80   4.9  196.0
# 8    6.1  156.0
# 92   5.2  110.0
# 79   6.5   90.0
# 23   4.7   87.0
# 85   5.8  166.0
# 34   4.8  163.0
# 90   7.3   86.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.95528441,  0.68957589],
#        [ 0.93240335,  0.68957589],
#        [-0.78367643,  1.33930191],
#        [ 0.84659936,  1.31331287],
#        [-0.69787244,  2.58677588],
#        [ 0.07436346, -1.12965698],
#        [ 0.84659936, -1.57147068],
#        [-0.01144053, -0.58388712],
#        [ 0.67499138, -0.89575561],
#        [ 1.79044324,  1.0794115 ],
#        [-0.2688525 ,  0.19578411],
#        [ 0.67499138, -0.32399671],
#        [-0.86948042, -1.59745972],
#        [-0.01144053, -2.06526245],
#        [ 1.79044324,  0.6375978 ],
#        [ 0.24597144,  0.09182794],
#        [ 0.16016745, -0.29800767],
#        [ 0.5033834 , -0.11608438],
#        [-1.12689239, -1.88333917],
#        [-0.86948042, -0.86976657],
#        [-0.18304851,  0.45567452],
#        [-0.2688525 ,  0.48166356],
#        [ 0.93240335, -1.98729533],
#        [ 0.5033834 ,  0.35171835],
#        [ 1.96205122,  1.13138958],
#        [-1.8133243 , -0.40196383],
#        [ 0.41757941,  0.92347725],
#        [-1.72752031, -1.28559123],
#        [-0.52626447, -0.45394192],
#        [ 0.07436346,  0.19578411],
#        [ 1.18981531,  0.19578411],
#        [-0.95528441, -1.6494378 ],
#        [ 0.58918739,  1.49523616],
#        [-1.0410884 ,  0.42968548],
#        [ 1.2756193 ,  0.14380603],
#        [ 2.13365919, -0.11608438],
#        [-0.78367643, -1.51949259],
#        [ 0.76079537, -0.73982137],
#        [-0.52626447,  0.27375123],
#        [ 1.10401133, -0.22004055],
#        [-0.61206845, -0.09009534],
#        [-1.38430436, -2.14322958],
#        [ 0.33177542, -0.22004055],
#        [ 0.84659936, -0.32399671],
#        [-0.2688525 ,  0.40369644],
#        [ 0.76079537,  0.35171835],
#        [-0.86948042, -0.16806246],
#        [ 1.53303127, -0.27201863],
#        [ 0.76079537,  0.3777074 ],
#        [ 0.24597144, -0.55789808],
#        [-0.01144053,  0.6375978 ],
#        [-1.72752031, -0.6358652 ],
#        [ 1.36142329, -0.92174465],
#        [ 1.10401133,  0.32572931],
#        [ 0.24597144,  0.0658389 ],
#        [ 0.67499138,  0.42968548],
#        [ 0.84659936,  1.93704985],
#        [-0.09724452, -0.47993096],
#        [-0.69787244,  0.19578411],
#        [ 1.2756193 ,  0.87149917],
#        [-2.32814824,  1.5212252 ],
#        [-1.12689239, -0.09009534],
#        [-0.95528441, -0.11608438],
#        [-0.01144053, -1.51949259],
#        [ 0.41757941,  0.14380603],
#        [-1.21269638,  0.55963068],
#        [-0.78367643,  0.09182794],
#        [ 0.84659936,  0.3777074 ],
#        [-0.52626447, -0.27201863],
#        [-0.52626447,  0.3777074 ],
#        [-1.0410884 ,  1.15737862],
#        [-1.0410884 , -0.32399671],
#        [-1.47010835,  1.96303889],
#        [ 0.33177542,  0.42968548],
#        [-0.01144053, -0.01212822],
#        [-0.69787244, -0.89575561],
#        [ 0.07436346, -0.55789808],
#        [ 1.70463925, -1.18163506],
#        [-0.95528441,  0.79353205],
#        [-0.2688525 ,  1.15737862],
#        [ 0.58918739,  0.76754301],
#        [-1.38430436,  0.6375978 ],
#        [ 1.36142329,  0.09182794],
#        [-2.15654026,  2.82067724],
#        [ 1.10401133, -1.93531725],
#        [-0.69787244,  0.9494663 ],
#        [ 1.2756193 , -1.6494378 ],
#        [-0.61206845, -0.27201863],
#        [-0.95528441,  0.24776219],
#        [ 0.67499138, -0.03811726]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.41757941, -2.27317478],
#        [ 0.07436346, -1.54548163],
#        [-0.95528441,  1.85908273],
#        [ 0.07436346,  0.81952109],
#        [-0.69787244, -0.37597479],
#        [ 0.41757941, -0.89575561],
#        [-1.12689239, -0.97372273],
#        [-0.18304851,  1.0794115 ],
#        [-1.0410884 ,  1.00144438],
#        [ 1.10401133, -0.99971177]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 82    1
# 56    0
# 80    0
# 8     0
# 92    0
# 79    1
# 23    0
# 85    1
# 34    0
# 90    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7

# %%
pip install mlxtend
# Out:
# Collecting mlxtendNote: you may need to restart the kernel to use updated packages.
#
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# INFO: pip is looking at multiple versions of mlxtend to determine which version is compatible with other requirements. This could take a while.
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (3.9.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mani\anaconda3\envs\myenv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
